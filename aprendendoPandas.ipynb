# %%
print('Esse é o arquivo que estou utilizando para aprender comandos do pandas, com intuito de fazer o desafio House Prices')
# Out:
# Esse é o arquivo que estou utilizando para aprender comandos do pandas, com intuito de fazer o desafio House Prices

# %%
#Importando o pandas como 'pd', para utilizar como comando
import pandas as pd

# %%
#Entendendo como funcionam dataframes
df = pd.DataFrame(
    {
        "Name": [
            "Braund, Mr. Owen Harris",
            "Allen, Mr. William Henry",
            "Bonnell, Miss. Elizabeth",
        ],
        "Age": [22, 35, 58],
        "Sex": ["male", "male", "female"],
    }
)

df
# Out:
#                        Name  Age     Sex
# 0   Braund, Mr. Owen Harris   22    male
# 1  Allen, Mr. William Henry   35    male
# 2  Bonnell, Miss. Elizabeth   58  female

# %%
#Chamando coluna uma única coluna 
df["Age"]
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
#Fazendo o pandas ler um arquivo csv 
dfTest = pd.read_csv('basesDadosHousePrices/test.csv')
dfTest
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
#Fazendo o pandas ler um arquivo csv 
dfTrain = pd.read_csv('basesDadosHousePrices/train.csv')
dfTrain
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
#Fazendo o pandas ler um arquivo csv 
dfSubmission = pd.read_csv('basesDadosHousePrices/sample_submission.csv')
dfSubmission
# Out:
#         Id      SalePrice
# 0     1461  169277.052498
# 1     1462  187758.393989
# 2     1463  183583.683570
# 3     1464  179317.477511
# 4     1465  150730.079977
# ...    ...            ...
# 1454  2915  167081.220949
# 1455  2916  164788.778231
# 1456  2917  219222.423400
# 1457  2918  184924.279659
# 1458  2919  187741.866657
#
# [1459 rows x 2 columns]

# %%
#Chamando coluna única no csv da base de dados test do House Prices
dfTest["LotArea"]
# Out:
# 0       11622
# 1       14267
# 2       13830
# 3        9978
# 4        5005
#         ...
# 1454     1936
# 1455     1894
# 1456    20000
# 1457    10441
# 1458     9627
# Name: LotArea, Length: 1459, dtype: int64

# %%
#Utilizando o head(), método que mostra as primeiras 5 linhas de uma tabela
dfTest.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
#Utilizando o .info() para entender dados nulos e não-nulos e os tipos de dados de um dataframe
dfTrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
#Utilizando .describe() para entender operações nas colunas:
#Contagem - count
#Média - mean
#Desvio Padrão - std
#Menor valor - min
#Maior valor - max
dfTrain.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
#Utilizando .sort_values() para ordenar os valores da coluna de tamanho da área do lote (menor para o maior)
dfTrain.sort_values(by='LotArea')
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 956    957         160       RM         24.0     1300   Pave   NaN      Reg
# 1039  1040         180       RM         21.0     1477   Pave   NaN      Reg
# 614    615         180       RM         21.0     1491   Pave   NaN      Reg
# 489    490         180       RM         21.0     1526   Pave   NaN      Reg
# 1038  1039         160       RM         21.0     1533   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 451    452          20       RL         62.0    70761   Pave   NaN      IR1
# 706    707          20       RL          NaN   115149   Pave   NaN      IR2
# 249    250          50       RL          NaN   159000   Pave   NaN      IR2
# 335    336         190       RL          NaN   164660   Grvl   NaN      IR1
# 313    314          20       RL        150.0   215245   Pave   NaN      IR3
#
# ...

# %%
#Utilizando .sort_values() para ordenar os valores da coluna de tamanho da área do lote (maior para o menor)
dfTrain.sort_values(by='LotArea', ascending=False)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 313    314          20       RL        150.0   215245   Pave   NaN      IR3
# 335    336         190       RL          NaN   164660   Grvl   NaN      IR1
# 249    250          50       RL          NaN   159000   Pave   NaN      IR2
# 706    707          20       RL          NaN   115149   Pave   NaN      IR2
# 451    452          20       RL         62.0    70761   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1449  1450         180       RM         21.0     1533   Pave   NaN      Reg
# 489    490         180       RM         21.0     1526   Pave   NaN      Reg
# 614    615         180       RM         21.0     1491   Pave   NaN      Reg
# 1039  1040         180       RM         21.0     1477   Pave   NaN      Reg
# 956    957         160       RM         24.0     1300   Pave   NaN      Reg
#
# ...

# %%
#Utilizando .sort_values() para ordenar os valores da coluna de preço de venda (maior para o menor)
dfTrain.sort_values(by='SalePrice', ascending=False)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
# 1169  1170          60       RL        118.0    35760   Pave   NaN      IR1
# 898    899          20       RL        100.0    12919   Pave   NaN      IR1
# 803    804          60       RL        107.0    13891   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 30      31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 533    534          20       RL         50.0     5000   Pave   NaN      Reg
# 968    969          50       RM         50.0     5925   Pave   NaN      Reg
# 916    917          20  C (all)         50.0     9000   Pave   NaN      Reg
# 495    496          30  C (all)         60.0     7879   Pave   NaN      Reg
#
# ...

# %%
#Utilizando .sort_values() para ordenar os valores da coluna de preço de venda (menor para o maior)
dfTrain.sort_values(by='SalePrice')
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 495    496          30  C (all)         60.0     7879   Pave   NaN      Reg
# 916    917          20  C (all)         50.0     9000   Pave   NaN      Reg
# 968    969          50       RM         50.0     5925   Pave   NaN      Reg
# 533    534          20       RL         50.0     5000   Pave   NaN      Reg
# 30      31          70  C (all)         50.0     8500   Pave  Pave      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 803    804          60       RL        107.0    13891   Pave   NaN      Reg
# 898    899          20       RL        100.0    12919   Pave   NaN      IR1
# 1169  1170          60       RL        118.0    35760   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
#
# ...
